# %% [markdown]
# ## This is a testing for ED Column case after training

# %%
import numpy as np
from kkthn import KKTHardNet

model = KKTHardNet(name='ED_Column')
model.load('/mnt/research/Hasan_Faruque/Shared/kkt-hardnet/notebooks/ED_Column_20260414_174201/metadata.json')

# %%
actual = np.array([0.115750079,1.653222442,0.000465029,0.999534971,1.84E-20,0.164683262,0.00141404,0.833902698,0.358825244])
predicted = model.predict([0.390345867,1.378626656,3.1])

# %%
error_mse = np.mean((actual - predicted) ** 2)
print(f'MSE: {error_mse}')
